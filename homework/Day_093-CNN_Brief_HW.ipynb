# %% [markdown]
# # 作業目標:
#     運用 Keras 模組建構CNN, 了解 CNN 的架構

# %% [markdown]
# # 作業重點
# (1)嘗試比對 Dense 與 layers.Conv2D 架構NN 的差異
#
# (2) 有沒有Pooling layer, 對於參數量的差異
#
# 注意: input_shape 請勿修改

# %%
#導入相關模組
import keras
from keras import layers
from keras import models
from keras.models import Sequential
from keras.layers import Conv2D, Activation, MaxPooling2D, Flatten, Dense

#確認keras 版本
print(keras.__version__)
# Out:
# Using TensorFlow backend.
# 2.2.4

# %%
model = Sequential([
    Dense(32, input_shape=(784,)),              
    Dense(units=100),
    Activation('relu'),
    Dense(units=10),
    Activation('softmax'),
])

model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0731 06:53:54.193132 139950557755264 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0731 06:53:54.238147 139950557755264 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0731 06:53:54.244857 139950557755264 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               3300
# _________________________________________________________________
# activation_1 (Activation)    (None, 100)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1010
# _________________________________________________________________
# activation_2 (Activation)    (None, 10)                0
# =================================================================
# Total params: 29,430
# Trainable params: 29,430
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # layers.Conv2D 模型, 用作比對
#
# ![CNN_Model.png](attachment:CNN_Model.png)

# %% [markdown]
# ### pooling

# %%
#建立一個序列模型
model = models.Sequential()
#建立兩個卷績層, 32 個內核, 內核大小 3x3, 
#輸入影像大小 28x28x1
model.add(layers.Conv2D(32,(3,3),input_shape=(28,28,1)))
#新增一池化層, 採用maxpooling
model.add(MaxPooling2D(2,2))
#建立第二個卷績層, 池化層, 
model.add(layers.Conv2D(25,(3,3)))
model.add(MaxPooling2D(2,2))
#新增平坦層
model.add(Flatten())
#建立一個全連接層
model.add(Dense(units=100))
model.add(Activation('relu'))

#建立一個輸出層, 並採用softmax
model.add(Dense(units=10))
model.add(Activation('softmax'))

model.summary()
# Out:
# W0731 06:53:54.353187 139950557755264 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 11, 11, 25)        7225
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 25)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 625)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               62600
# _________________________________________________________________
# activation_3 (Activation)    (None, 100)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                1010
# _________________________________________________________________
# activation_4 (Activation)    (None, 10)                0
# =================================================================
# Total params: 71,155
# Trainable params: 71,155
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 無 pooling

# %%
#建立一個序列模型
model = models.Sequential()
#建立兩個卷績層, 32 個內核, 內核大小 3x3, 
#輸入影像大小 28x28x1
model.add(layers.Conv2D(32,(3,3),input_shape=(28,28,1)))
#建立第二個卷績層
model.add(layers.Conv2D(25,(3,3)))
#新增平坦層
model.add(Flatten())
#建立一個全連接層
model.add(Dense(units=100))
model.add(Activation('relu'))

#建立一個輸出層, 並採用softmax
model.add(Dense(units=10))
model.add(Activation('softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 24, 24, 25)        7225
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 14400)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               1440100
# _________________________________________________________________
# activation_5 (Activation)    (None, 100)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                1010
# _________________________________________________________________
# activation_6 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,448,655
# Trainable params: 1,448,655
# Non-trainable params: 0
# _________________________________________________________________
